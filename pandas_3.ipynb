# %% [markdown]
# <a href="https://colab.research.google.com/github/SuryaAbyss/Web_Dev/blob/main/pandas_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {"Apples":[102,500,250,75],"Grapes":[50,150,90,45]}
df = pd.DataFrame(data,index=["A","B","C","D"])

# %%
df
# Out:
#    Apples  Grapes
# A     102      50
# B     500     150
# C     250      90
# D      75      45

# %%
df['Grapes']
# Out:
# 0     50
# 1    150
# 2     90
# 3     45
# Name: Grapes, dtype: int64

# %%
df[['Grapes']]
# Out:
#    Grapes
# 0      50
# 1     150
# 2      90
# 3      45

# %%
df['bananas'] = df['Grapes'] + 50

# %%
df
# Out:
#    Apples  Grapes  bananas
# A     102      50      100
# B     500     150      200
# C     250      90      140
# D      75      45       95

# %%
df.drop(['bananas'],axis=1)
# Out:
#    Apples  Grapes
# 0     102      50
# 1     500     150
# 2     250      90
# 3      75      45

# %%
df
# Out:
#    Apples  Grapes  bananas
# A     102      50      100
# B     500     150      200
# C     250      90      140
# D      75      45       95

# %%
df.drop(['bananas'],axis=1, inplace = True)  #inplcae for permanent delete by def inplace is set as False

# %%
df
# Out:
#    Apples  Grapes
# 0     102      50
# 1     500     150
# 2     250      90
# 3      75      45

# %%
df['pear'] = df['bananas'] + 100
df['Mangoes'] = df['pear'] + 500
df['Jackfruit'] = df['Grapes'] + 150
df['Strawberry'] = df['Apples'] + 200
df['Oranges'] = df['Grapes'] + 70

# %%
df
# Out:
#    Apples  Grapes  bananas  pear  Mangoes  Jackfruit  Strawberry  Oranges
# A     102      50      100   200      700        200         302      120
# B     500     150      200   300      800        300         700      220
# C     250      90      140   240      740        240         450      160
# D      75      45       95   195      695        195         275      115

# %% [markdown]
# # Row Selection
# 1. loc
# 2. iloc

# %%
df.loc[3]
# Out:
# Apples         75
# Grapes         45
# pear          195
# Mangoes       695
# bananas        95
# Jackfruit     195
# Strawberry    275
# Oranges       115
# Name: 3, dtype: int64

# %%
df.loc[[3]] #locktakes index_name like A,B,C....
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-a5bcd390397e> in <cell line: 1>()
# ----> 1 df.loc[[3]] #lock works with index
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1101
#    1102             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103             return self._getitem_axis(maybe_callable, axis=axis)
#    1104
#    1105     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1330                     raise ValueError("Cannot index with multidimensional key")
#    1331
# -> 1332                 return self._getitem_iterable(key, axis=axis)
#    1333
#    1334             # nested tuple slicing
#
# ...

# %%
df.iloc[[3]] #It takes index number
# Out:
#    Apples  Grapes  bananas  pear  Mangoes  Jackfruit  Strawberry  Oranges
# D      75      45       95   195      695        195         275      115

# %%
df.loc[['D']]
# Out:
#    Apples  Grapes  bananas  pear  Mangoes  Jackfruit  Strawberry  Oranges
# D      75      45       95   195      695        195         275      115

# %%
df
# Out:
#    Apples  Grapes  bananas  pear  Mangoes  Jackfruit  Strawberry  Oranges
# A     102      50      100   200      700        200         302      120
# B     500     150      200   300      800        300         700      220
# C     250      90      140   240      740        240         450      160
# D      75      45       95   195      695        195         275      115

# %%
df.iloc[2:3]
# Out:
#    Apples  Grapes  bananas  pear  Mangoes  Jackfruit  Strawberry  Oranges
# C     250      90      140   240      740        240         450      160

# %%
df.loc['A':'D']
# Out:
#    Apples  Grapes  bananas  pear  Mangoes  Jackfruit  Strawberry  Oranges
# A     102      50      100   200      700        200         302      120
# B     500     150      200   300      800        300         700      220
# C     250      90      140   240      740        240         450      160
# D      75      45       95   195      695        195         275      115

# %%
students_marks = {"Name":["Rahul","Rohit","VenKat","Sahil","Ankita"],
                  "OS":[25,75.5,96,0,100],'DBMS':[20,80,60,50,99]}

df1 = pd.DataFrame(students_marks)

# %%
df1
# Out:
#      Name     OS  DBMS
# 0   Rahul   25.0    20
# 1   Rohit   75.5    80
# 2  VenKat   96.0    60
# 3   Sahil    0.0    50
# 4  Ankita  100.0    99

# %%
data2 = {"Name":"Robby", "OS":60.5, "DBMS":55.5}

# %%
#1st method
data2_df = pd.DataFrame(data2, index=[0])
df1 = pd.concat([df1, data2_df], ignore_index=True)

# %%
df1
# Out:
#      Name     OS  DBMS
# 0   Rahul   25.0  20.0
# 1   Rohit   75.5  80.0
# 2  VenKat   96.0  60.0
# 3   Sahil    0.0  50.0
# 4  Ankita  100.0  99.0
# 5   Robby   60.5  55.5

# %%
data3 = {"Name":"Venom", "OS":80.5, "DBMS":75}

# %%
df1.loc[4] = ['Logan',78,69]

# %%
df1
# Out:
#      Name    OS  DBMS
# 0   Rahul  25.0  20.0
# 1   Rohit  75.5  80.0
# 2  VenKat  96.0  60.0
# 3   Sahil   0.0  50.0
# 4   Logan  78.0  69.0
# 5   Robby  60.5  55.5

# %% [markdown]
# # Deletion

# %%
del df1.loc[[5]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-e7734d9c092e> in <cell line: 1>()
# ----> 1 del df1.loc[[5]]
#
# AttributeError: __delitem__

# %%
df1.loc.pop([6])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-a2dd32e6bf94> in <cell line: 1>()
# ----> 1 df1.loc.pop([6])
#
# AttributeError: '_LocIndexer' object has no attribute 'pop'

# %%
df1.drop(5) #deletion
# Out:
#      Name    OS  DBMS
# 0   Rahul  25.0  20.0
# 1   Rohit  75.5  80.0
# 2  VenKat  96.0  60.0
# 3   Sahil   0.0  50.0
# 4   Logan  78.0  69.0

# %%
df1
# Out:
#      Name    OS  DBMS
# 0   Rahul  25.0  20.0
# 1   Rohit  75.5  80.0
# 2  VenKat  96.0  60.0
# 3   Sahil   0.0  50.0
# 4   Logan  78.0  69.0
# 5   Robby  60.5  55.5

# %%
df1.drop(5, inplace= True)

# %% [markdown]
# # Why Python is used
#  * Data Exploration
#  * Data Cleaning
#  * Data Manipulation
#  * Data Analysis

# %% [markdown]
# # Head - It will provide a certain part of a larger data

# %%
df1
# Out:
#      Name    OS  DBMS
# 0   Rahul  25.0  20.0
# 1   Rohit  75.5  80.0
# 2  VenKat  96.0  60.0
# 3   Sahil   0.0  50.0
# 4   Logan  78.0  69.0
# 5   Gaaby  40.3  19.5

# %%
data2 = {"Name":"Tahir", "OS":69, "DBMS":73}
data2_df = pd.DataFrame(data2, index=[0])
df1 = pd.concat([df1, data2_df], ignore_index=True)

# %%
df1
# Out:
#       Name    OS  DBMS
# 0    Rahul  25.0  20.0
# 1    Rohit  75.5  80.0
# 2   VenKat  96.0  60.0
# 3    Sahil   0.0  50.0
# 4    Logan  78.0  69.0
# 5    Gaaby  40.3  19.5
# 6   Ashika  99.0  65.0
# 7  Nishant  79.0  35.9
# 8    Tahir  69.0  73.0

# %%
df1.head() # it is only providing a little part of that data
# Out:
#      Name    OS  DBMS
# 0   Rahul  25.0  20.0
# 1   Rohit  75.5  80.0
# 2  VenKat  96.0  60.0
# 3   Sahil   0.0  50.0
# 4   Logan  78.0  69.0

# %%
df1.tail() # it will return small portion of last
# Out:
#       Name    OS  DBMS
# 4    Logan  78.0  69.0
# 5    Gaaby  40.3  19.5
# 6   Ashika  99.0  65.0
# 7  Nishant  79.0  35.9
# 8    Tahir  69.0  73.0

# %%
df1.head(2)
# Out:
#     Name    OS  DBMS
# 0  Rahul  25.0  20.0
# 1  Rohit  75.5  80.0

# %%
df1.tail(2)
# Out:
#       Name    OS  DBMS
# 7  Nishant  79.0  35.9
# 8    Tahir  69.0  73.0

# %% [markdown]
# # dtypes - checks the data types

# %%
df1.dtypes
# Out:
# Name     object
# OS      float64
# DBMS    float64
# dtype: object

# %% [markdown]
# # empty - it will check is the dataframe is empty or not

# %%
df1.empty
# Out:
# False

# %% [markdown]
# # ndim - it will show the dimension

# %%
df1.ndim
# Out:
# 2

# %% [markdown]
# # shape-it will represent the shape

# %%
df1.shape
# Out:
# (9, 3)

# %% [markdown]
# # size - no of elements

# %%
df1.size
# Out:
# 27

# %% [markdown]
# # Values- it will return all the values in array

# %%
df1.values
# Out:
# array([['Rahul', 25.0, 20.0],
#        ['Rohit', 75.5, 80.0],
#        ['VenKat', 96.0, 60.0],
#        ['Sahil', 0.0, 50.0],
#        ['Logan', 78.0, 69.0],
#        ['Gaaby', 40.3, 19.5],
#        ['Ashika', 99.0, 65.0],
#        ['Nishant', 79.0, 35.9],
#        ['Tahir', 69.0, 73.0]], dtype=object)

# %% [markdown]
# # describe - statistical info

# %%
df1.describe()
# Out:
#               OS       DBMS
# count   9.000000   9.000000
# mean   62.422222  52.488889
# std    33.510326  22.606163
# min     0.000000  19.500000
# 25%    40.300000  35.900000
# 50%    75.500000  60.000000
# 75%    79.000000  69.000000
# max    99.000000  80.000000

# %% [markdown]
# # transpose - T Rows and columns gets exchanged

# %%
df1.T
# Out:
#           0      1       2      3      4      5       6        7      8
# Name  Rahul  Rohit  VenKat  Sahil  Logan  Gaaby  Ashika  Nishant  Tahir
# OS     25.0   75.5    96.0    0.0   78.0   40.3    99.0     79.0   69.0
# DBMS   20.0   80.0    60.0   50.0   69.0   19.5    65.0     35.9   73.0

# %%
df1.iloc[1]
# Out:
# Name    Rohit
# OS       75.5
# DBMS     80.0
# Name: 1, dtype: object

# %% [markdown]
# # Sum

# %%
df1.sum()
# Out:
# Name    RahulRohitVenKatSahilLoganGaabyAshikaNishantTahir
# OS                                                  561.8
# DBMS                                                472.4
# dtype: object

# %%
df1['OS'].sum()
# Out:
# 561.8

# %% [markdown]
# # MEAN error occuring!!!

# %%
df1
# Out:
#       Name    OS  DBMS
# 0    Rahul  25.0  20.0
# 1    Rohit  75.5  80.0
# 2   VenKat  96.0  60.0
# 3    Sahil   0.0  50.0
# 4    Logan  78.0  69.0
# 5    Gaaby  40.3  19.5
# 6   Ashika  99.0  65.0
# 7  Nishant  79.0  35.9
# 8    Tahir  69.0  73.0

# %%
df1.mode()
# Out:
#       Name    OS  DBMS
# 0   Ashika   0.0  19.5
# 1    Gaaby  25.0  20.0
# 2    Logan  40.3  35.9
# 3  Nishant  69.0  50.0
# 4    Rahul  75.5  60.0
# 5    Rohit  78.0  65.0
# 6    Sahil  79.0  69.0
# 7    Tahir  96.0  73.0
# 8   VenKat  99.0  80.0

# %% [markdown]
# # std-standard deviation

# %%
# Convert all columns to numeric types
df1 = df1.apply(pd.to_numeric, errors='coerce')

# Remove any rows that contain non-numeric values
df1 = df1.dropna()

# Calculate the standard deviation
std_values = df1.std()

# Print the standard deviation
print(std_values)
# Out:
# Name   NaN
# OS     NaN
# DBMS   NaN
# dtype: float64

# %%
df1.std()
# Out:
# Name   NaN
# OS     NaN
# DBMS   NaN
# dtype: float64

# %%
df1
# Out:
# Empty DataFrame
# Columns: [Name, OS, DBMS]
# Index: []

# %%
data2 = {"Name":"Jatin", "OS":94, "DBMS":-30}
data2_df = pd.DataFrame(data2, index=[0])
df1 = pd.concat([df1, data2_df], ignore_index=True)

# %%
df1
# Out:
#     Name    OS  DBMS
# 0  Tahir  69.0  73.0
# 1    Sas  22.0  33.0
# 2    Ram  45.0  83.0
# 3    Aju  89.0  89.0
# 4  Papil  54.0 -90.0
# 5  Jatin  94.0 -30.0

# %% [markdown]
# # Min & Max

# %%
df1.min()
# Out:
# Name     Aju
# OS      22.0
# DBMS   -90.0
# dtype: object

# %%
df1.max()
# Out:
# Name    Tahir
# OS       94.0
# DBMS     89.0
# dtype: object
