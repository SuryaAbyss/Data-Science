# %% [markdown]
# <a href="https://colab.research.google.com/github/SuryaAbyss/Web_Dev/blob/main/Pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DataFrame
# 1. It is a 2D DS

# %%
#SYNTAX: pd.DateFrame(data, index, columns, dtype, copy)

# %%
#Starting With CRUD

# %% [markdown]
# # Creating
# * Ways to create a DataFrame
# 1. List
# 2. Dict
# 3. ndARRAY
# 4. Series
# 5. Another Dataframe

# %%
import pandas as pd

# %%
df = pd.DataFrame  ##empty

# %%
df
# Out:
# pandas.core.frame.DataFrame

# %%
data = [1,2,3,4,5]
df = pd.DataFrame(data)

# %%
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
data = [["DOG",'Barks'],['Cat','MEOW'],['Lion','ROAR']]
df= pd.DataFrame(data)

# %%
df
# Out:
#       0      1
# 0   DOG  Barks
# 1   Cat   MEOW
# 2  Lion   ROAR

# %%
data = [["DOG",'Barks'],['Cat','MEOW'],['Lion','ROAR']]
df= pd.DataFrame(data,columns = ["ANIMAL_NAME","ANIMAL_SOUND"])

# %%
df
# Out:
#   ANIMAL_NAME ANIMAL_SOUND
# 0         DOG        Barks
# 1         Cat         MEOW
# 2        Lion         ROAR

# %%
data = {"Name":["ram","Rahul","Bhavana"],"Age":[25,20,22]}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age
# 0      ram   25
# 1    Rahul   20
# 2  Bhavana   22

# %%
data = {"Name":["ram","Rahul","Bhavana"],"Age":[25,20,22]}
df = pd.DataFrame(data,index = ["A","B","C"])

# %%
df
# Out:
#       Name  Age
# A      ram   25
# B    Rahul   20
# C  Bhavana   22

# %%
data = {"Name":["ram","Rahul","Bhavana"],"Age":[25,20,22]}
df = pd.DataFrame(data,index = ["A","B","C","D"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-83d2e16add94> in <cell line: 2>()
#       1 data = {"Name":["ram","Rahul","Bhavana"],"Age":[25,20,22]}
# ----> 2 df = pd.DataFrame(data,index = ["A","B","C","D"])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     707         elif isinstance(data, dict):
#     708             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710         elif isinstance(data, ma.MaskedArray):
#     711             from numpy.ma import mrecords
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
data = {"Karana Marks-xav":pd.Series([50,40,77,99],index=["test_1","test_2","test_3",'test_4']),
        "Arjun MarksMGEM":pd.Series([44,99,67,36,48],index=["test_1","ptest_1","test_2","ptest_2","test3"])}
df = pd.DataFrame(data)

# %%
df
# Out:
#          Karana Marks-xav  Arjun MarksMGEM
# ptest_1               NaN             99.0
# ptest_2               NaN             36.0
# test3                 NaN             48.0
# test_1               50.0             44.0
# test_2               40.0             67.0
# test_3               77.0              NaN
# test_4               99.0              NaN

# %%
data = [{"a":1,"b":2},{"c":3,"d":4},{"e":5,"f":6}]
df = pd.DataFrame(data)

# %%
df
# Out:
#      a    b    c    d    e    f
# 0  1.0  2.0  NaN  NaN  NaN  NaN
# 1  NaN  NaN  3.0  4.0  NaN  NaN
# 2  NaN  NaN  NaN  NaN  5.0  6.0

# %%
data = [{"a":1,"b":2},{"c":3,"d":4},{"e":5,"f":6}]
df = pd.DataFrame(data,index=["x","y","z"])

# %%
df
# Out:
#      a    b    c    d    e    f
# x  1.0  2.0  NaN  NaN  NaN  NaN
# y  NaN  NaN  3.0  4.0  NaN  NaN
# z  NaN  NaN  NaN  NaN  5.0  6.0

# %% [markdown]
# # Updation

# %%
data = [10,20,30,40,50,60,70]
data1 = [100,200,300,400,500,600,700]
df = pd.DataFrame([data,data1], columns=["a","b","c","d","e","e",'f'])

# %%
df
# Out:
#      a    b    c    d    e    e    f
# 0   10   20   30   40   50   60   70
# 1  100  200  300  400  500  600  700

# %%
df['b']
# Out:
# 0     20
# 1    200
# Name: b, dtype: int64

# %%
df['f']
# Out:
# 0     70
# 1    700
# Name: f, dtype: int64

# %% [markdown]
# # Adding the column

# %%
df['h'] = [55,87]

# %%
df
# Out:
#      a    b    c    d    e    e    f   h
# 0   10   20   30   40   50   60   70  55
# 1  100  200  300  400  500  600  700  87

# %%
df['m'] = [56,78,99]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-3b1f22a628df> in <cell line: 1>()
# ----> 1 df['m'] = [56,78,99]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3948         else:
#    3949             # set column
# -> 3950             self._set_item(key, value)
#    3951
#    3952     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4141         ensure homogeneity.
#    4142         """
# -> 4143         value = self._sanitize_column(value)
#    4144
#    4145         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4868
#    4869         if is_list_like(value):
# -> 4870             com.require_length_match(value, self.index)
# ...

# %%
df['m'] = pd.Series([56,78,99])

# %%
df
# Out:
#      a    b    c    d    e    e    f   h   m
# 0   10   20   30   40   50   60   70  55  56
# 1  100  200  300  400  500  600  700  87  78

# %%
df['z'] = pd.Series([1,2,3,4],index=[0,1,2,3])

# %%
df
# Out:
#      a    b    c    d    e    e    f   h   m  z
# 0   10   20   30   40   50   60   70  55  56  1
# 1  100  200  300  400  500  600  700  87  78  2

# %%
df['z']
# Out:
# 0    1
# 1    2
# Name: z, dtype: int64

# %%
df['y'] = pd.Series([1,2,3,4],index=['a','b','c','d'])

# %%
df
# Out:
#      a    b    c    d    e    e    f   h   m  z   y
# 0   10   20   30   40   50   60   70  55  56  1 NaN
# 1  100  200  300  400  500  600  700  87  78  2 NaN

# %% [markdown]
# # Deleting

# %%
del df["b"] #deleting the column using del

# %%
df
# Out:
#      a    c    d    e    e    f   h   m  z   y
# 0   10   30   40   50   60   70  55  56  1 NaN
# 1  100  300  400  500  600  700  87  78  2 NaN

# %%
#pop function
df.pop("z")
# Out:
# 0    1
# 1    2
# Name: z, dtype: int64

# %%
df
# Out:
#      a    c    d    e    e    f   h   m   y
# 0   10   30   40   50   60   70  55  56 NaN
# 1  100  300  400  500  600  700  87  78 NaN

# %%
df[['c']]
# Out:
#      c
# 0   30
# 1  300

# %%
df[['f',"a","m"]]
# Out:
#      f    a   m
# 0   70   10  56
# 1  700  100  78

# %%
df['f',"a","m"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# TypeError: only integer scalar arrays can be converted to a scalar index
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
df
# Out:
#      a    c    d    e    e    f   h   m   y
# 0   10   30   40   50   60   70  55  56 NaN
# 1  100  300  400  500  600  700  87  78 NaN

# %%
del df[['f','e']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '['f', 'e']' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-66-41420b5df3a0> in <cell line: 1>()
# ----> 1 del df[['f','e']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __delitem__(self, key)
# ...

# %%
df.pop("f","e") #del and pop can't delete multiple columns
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-56479d64d560> in <cell line: 1>()
# ----> 1 df.pop("f","e")
#
# TypeError: DataFrame.pop() takes 2 positional arguments but 3 were given

# %%
#drop()  delete multiple but not perment
df.drop(['f','e'],axis=1)
# Out:
#      a    c    d   h   m   y
# 0   10   30   40  55  56 NaN
# 1  100  300  400  87  78 NaN

# %%
df
# Out:
#      a    c    d    e    e    f   h   m   y
# 0   10   30   40   50   60   70  55  56 NaN
# 1  100  300  400  500  600  700  87  78 NaN

# %%
df['p'] = df['a'] + df['c']

# %%
df
# Out:
#      a    c    d    e    e    f   h   m   y    p
# 0   10   30   40   50   60   70  55  56 NaN   40
# 1  100  300  400  500  600  700  87  78 NaN  400

# %%
df1 = [{"a":22,"d":33,"c":44}]

df = df.append(df1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-1dd1a3b24751> in <cell line: 3>()
#       1 df1 = [{"a":22,"d":33,"c":44}]
#       2
# ----> 3 df = df.append(df1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'append'
