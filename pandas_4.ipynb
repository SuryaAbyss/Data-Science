# %% [markdown]
# <a href="https://colab.research.google.com/github/SuryaAbyss/Web_Dev/blob/main/pandas_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data1 = np.random.randn(10, 3)
data2 = np.random.randn(7, 3)

# %%
df1 = pd.DataFrame(data1, columns=['Col1', 'Col2', 'Col3'])
df2 = pd.DataFrame(data2, columns=['Col1', 'Col2', 'Col3'])

# %%
df1
# Out:
#        Col1      Col2      Col3
# 0  0.938152  0.867968  0.564309
# 1  0.136084  1.509564  0.413173
# 2 -0.260248  0.305436  1.823351
# 3  0.379587  0.173985 -1.377775
# 4  0.210223 -1.174838 -0.076621
# 5  0.221666 -0.345368 -0.295314
# 6  0.135381 -0.073217  0.614648
# 7  1.143142  1.258651 -0.015399
# 8 -0.749284  0.083847 -0.551462
# 9  0.729565 -0.425768 -1.117910

# %%
df2
# Out:
#        Col1      Col2      Col3
# 0  1.744899 -0.915024 -0.513621
# 1  1.093726 -0.103071  2.193583
# 2 -1.222110 -0.545477  0.816354
# 3 -0.707525  0.734215  0.139738
# 4 -0.151864 -0.505305 -0.685257
# 5 -0.031176  0.518940  1.634751
# 6 -1.312724  0.191412  0.699851

# %%
df3 = [df1 + df2]

# %%
df3
# Out:
# [       Col1      Col2      Col3
#  0  2.683051 -0.047056  0.050688
#  1  1.229810  1.406493  2.606756
#  2 -1.482359 -0.240040  2.639705
#  3 -0.327939  0.908199 -1.238037
#  4  0.058358 -1.680143 -0.761878
#  5  0.190490  0.173572  1.339437
#  6 -1.177343  0.118195  1.314499
#  7       NaN       NaN       NaN
#  8       NaN       NaN       NaN
#  9       NaN       NaN       NaN]

# %%
df3 = pd.concat([df1,df2]) #trying different things in concat

# %%
df3
# Out:
#        Col1      Col2      Col3
# 0  0.938152  0.867968  0.564309
# 1  0.136084  1.509564  0.413173
# 2 -0.260248  0.305436  1.823351
# 3  0.379587  0.173985 -1.377775
# 4  0.210223 -1.174838 -0.076621
# 5  0.221666 -0.345368 -0.295314
# 6  0.135381 -0.073217  0.614648
# 7  1.143142  1.258651 -0.015399
# 8 -0.749284  0.083847 -0.551462
# 9  0.729565 -0.425768 -1.117910
# 0  1.744899 -0.915024 -0.513621
# 1  1.093726 -0.103071  2.193583
# 2 -1.222110 -0.545477  0.816354
# 3 -0.707525  0.734215  0.139738
# 4 -0.151864 -0.505305 -0.685257
# 5 -0.031176  0.518940  1.634751
# 6 -1.312724  0.191412  0.699851

# %%
df3 = pd.concat([df1,df2],axis=1) #axis 1 puts it on the right side of it

# %%
df3
# Out:
#        Col1      Col2      Col3      Col1      Col2      Col3
# 0  0.938152  0.867968  0.564309  1.744899 -0.915024 -0.513621
# 1  0.136084  1.509564  0.413173  1.093726 -0.103071  2.193583
# 2 -0.260248  0.305436  1.823351 -1.222110 -0.545477  0.816354
# 3  0.379587  0.173985 -1.377775 -0.707525  0.734215  0.139738
# 4  0.210223 -1.174838 -0.076621 -0.151864 -0.505305 -0.685257
# 5  0.221666 -0.345368 -0.295314 -0.031176  0.518940  1.634751
# 6  0.135381 -0.073217  0.614648 -1.312724  0.191412  0.699851
# 7  1.143142  1.258651 -0.015399       NaN       NaN       NaN
# 8 -0.749284  0.083847 -0.551462       NaN       NaN       NaN
# 9  0.729565 -0.425768 -1.117910       NaN       NaN       NaN

# %%
df3 = pd.concat([df1,df2], ignore_index=True) #it makes corect indexing

# %%
df3
# Out:
#         Col1      Col2      Col3
# 0   0.938152  0.867968  0.564309
# 1   0.136084  1.509564  0.413173
# 2  -0.260248  0.305436  1.823351
# 3   0.379587  0.173985 -1.377775
# 4   0.210223 -1.174838 -0.076621
# 5   0.221666 -0.345368 -0.295314
# 6   0.135381 -0.073217  0.614648
# 7   1.143142  1.258651 -0.015399
# 8  -0.749284  0.083847 -0.551462
# 9   0.729565 -0.425768 -1.117910
# 10  1.744899 -0.915024 -0.513621
# 11  1.093726 -0.103071  2.193583
# 12 -1.222110 -0.545477  0.816354
# 13 -0.707525  0.734215  0.139738
# 14 -0.151864 -0.505305 -0.685257
# 15 -0.031176  0.518940  1.634751
# 16 -1.312724  0.191412  0.699851

# %%
df3["Col3"]
# Out:
# 0     0.564309
# 1     0.413173
# 2     1.823351
# 3    -1.377775
# 4    -0.076621
# 5    -0.295314
# 6     0.614648
# 7    -0.015399
# 8    -0.551462
# 9    -1.117910
# 10   -0.513621
# 11    2.193583
# 12    0.816354
# 13    0.139738
# 14   -0.685257
# 15    1.634751
# 16    0.699851
# Name: Col3, dtype: float64

# %% [markdown]
# # iteritems changed to items()

# %%
for key,value in df3.items():
  print(key,value)   #this for columns
# Out:
# Col1 0     0.938152
# 1     0.136084
# 2    -0.260248
# 3     0.379587
# 4     0.210223
# 5     0.221666
# 6     0.135381
# 7     1.143142
# 8    -0.749284
# 9     0.729565
# 10    1.744899
# 11    1.093726
# 12   -1.222110
# 13   -0.707525
# 14   -0.151864
# 15   -0.031176
# 16   -1.312724
# Name: Col1, dtype: float64
# Col2 0     0.867968
# 1     1.509564
# 2     0.305436
# 3     0.173985
# 4    -1.174838
# 5    -0.345368
# 6    -0.073217
# 7     1.258651
# 8     0.083847
# 9    -0.425768
# 10   -0.915024
# 11   -0.103071
# 12   -0.545477
# 13    0.734215
# 14   -0.505305
# 15    0.518940
# 16    0.191412
# Name: Col2, dtype: float64
# Col3 0     0.564309
# 1     0.413173
# 2     1.823351
# 3    -1.377775
# 4    -0.076621
# 5    -0.295314
# 6     0.614648
# 7    -0.015399
# 8    -0.551462
# 9    -1.117910
# 10   -0.513621
# 11    2.193583
# 12    0.816354
# 13    0.139738
# 14   -0.685257
# 15    1.634751
# 16    0.699851
# Name: Col3, dtype: float64

# %%
# !pip install --upgrade pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 28.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 2.2.2 which is incompatible.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 2.2.2 which is incompatible.
# ...

# %%
# Change df3.itemrows() to df3.iterrows()
for index, row in df3.iterrows():
    print(index, row)
# Out:
# 0 Col1    0.938152
# Col2    0.867968
# Col3    0.564309
# Name: 0, dtype: float64
# 1 Col1    0.136084
# Col2    1.509564
# Col3    0.413173
# Name: 1, dtype: float64
# 2 Col1   -0.260248
# Col2    0.305436
# Col3    1.823351
# Name: 2, dtype: float64
# 3 Col1    0.379587
# Col2    0.173985
# Col3   -1.377775
# Name: 3, dtype: float64
# 4 Col1    0.210223
# Col2   -1.174838
# Col3   -0.076621
# Name: 4, dtype: float64
# 5 Col1    0.221666
# Col2   -0.345368
# Col3   -0.295314
# Name: 5, dtype: float64
# 6 Col1    0.135381
# Col2   -0.073217
# Col3    0.614648
# Name: 6, dtype: float64
# 7 Col1    1.143142
# Col2    1.258651
# Col3   -0.015399
# Name: 7, dtype: float64
# 8 Col1   -0.749284
# Col2    0.083847
# Col3   -0.551462
# Name: 8, dtype: float64
# 9 Col1    0.729565
# Col2   -0.425768
# Col3   -1.117910
# Name: 9, dtype: float64
# 10 Col1    1.744899
# Col2   -0.915024
# Col3   -0.513621
# Name: 10, dtype: float64
# 11 Col1    1.093726
# Col2   -0.103071
# Col3    2.193583
# ...

# %% [markdown]
# # sorting

# %%
unsorted_df = pd.DataFrame(np.random.randn(9,3),
                           index = [5,7,3,9,2,9,22,21,4],
                           columns = [ 'Col1','Col2','Col3'])

# %%
 unsorted_df
# Out:
#         Col1      Col2      Col3
# 5   0.287628  1.449623 -0.205359
# 7  -0.122641  1.741591 -0.647847
# 3   0.126937  1.744315  0.079688
# 9   1.017972 -0.661539  0.345201
# 2   0.034861 -0.688402  0.879216
# 9   0.782861  0.707153 -0.191359
# 22  0.932736  0.803873 -1.134507
# 21 -0.873140  1.573112 -2.006006
# 4  -0.484870  0.041746  0.499454

# %%
unsorted_df.sort_index() #sorting
# Out:
#         Col1      Col2      Col3
# 2   2.201024 -0.028372 -0.703791
# 3  -0.586192  1.572089 -1.020588
# 4  -0.517675  0.081429 -0.290312
# 5  -0.625586 -0.505623  0.900586
# 7   0.168728  0.707410 -2.378795
# 9   1.072029 -0.020679 -0.369701
# 9  -0.604678  0.637382 -0.791869
# 21  1.593705 -1.495125  0.326773
# 22 -1.785685 -0.264007  0.685988

# %%
unsorted_df.sort_index(ascending=False) #this sorting in rows
# Out:
#         Col1      Col2      Col3
# 22 -1.785685 -0.264007  0.685988
# 21  1.593705 -1.495125  0.326773
# 9   1.072029 -0.020679 -0.369701
# 9  -0.604678  0.637382 -0.791869
# 7   0.168728  0.707410 -2.378795
# 5  -0.625586 -0.505623  0.900586
# 4  -0.517675  0.081429 -0.290312
# 3  -0.586192  1.572089 -1.020588
# 2   2.201024 -0.028372 -0.703791

# %%
unsorted_df.sort_index(axis=1)
# Out:
#         Col1      Col2      Col3
# 5  -0.625586 -0.505623  0.900586
# 7   0.168728  0.707410 -2.378795
# 3  -0.586192  1.572089 -1.020588
# 9   1.072029 -0.020679 -0.369701
# 2   2.201024 -0.028372 -0.703791
# 9  -0.604678  0.637382 -0.791869
# 22 -1.785685 -0.264007  0.685988
# 21  1.593705 -1.495125  0.326773
# 4  -0.517675  0.081429 -0.290312

# %%
unsorted_df.sort_index(axis=1,ascending=False)
# Out:
#         Col3      Col2      Col1
# 5   0.900586 -0.505623 -0.625586
# 7  -2.378795  0.707410  0.168728
# 3  -1.020588  1.572089 -0.586192
# 9  -0.369701 -0.020679  1.072029
# 2  -0.703791 -0.028372  2.201024
# 9  -0.791869  0.637382 -0.604678
# 22  0.685988 -0.264007 -1.785685
# 21  0.326773 -1.495125  1.593705
# 4  -0.290312  0.081429 -0.517675

# %% [markdown]
# # Sort_value()

# %%
df= pd.DataFrame({"Apples":[50,95,105,75], "Grapes":[90,23,10,56]})

# %%
df
# Out:
#    Apples  Grapes
# 0      50      90
# 1      95      23
# 2     105      10
# 3      75      56

# %%
df.sort_values(by='Apples')
# Out:
#    Apples  Grapes
# 0      50      90
# 3      75      56
# 1      95      23
# 2     105      10

# %%
df.sort_values(by=['Apples','Grapes'])
# Out:
#    Apples  Grapes
# 0      50      90
# 3      75      56
# 1      95      23
# 2     105      10

# %% [markdown]
# # Stat-Advanced

# %%
df3
# Out:
#         Col1      Col2      Col3
# 0   0.938152  0.867968  0.564309
# 1   0.136084  1.509564  0.413173
# 2  -0.260248  0.305436  1.823351
# 3   0.379587  0.173985 -1.377775
# 4   0.210223 -1.174838 -0.076621
# 5   0.221666 -0.345368 -0.295314
# 6   0.135381 -0.073217  0.614648
# 7   1.143142  1.258651 -0.015399
# 8  -0.749284  0.083847 -0.551462
# 9   0.729565 -0.425768 -1.117910
# 10  1.744899 -0.915024 -0.513621
# 11  1.093726 -0.103071  2.193583
# 12 -1.222110 -0.545477  0.816354
# 13 -0.707525  0.734215  0.139738
# 14 -0.151864 -0.505305 -0.685257
# 15 -0.031176  0.518940  1.634751
# 16 -1.312724  0.191412  0.699851

# %%
df3.head(7) #it is a view of only seven it is not deleteing aor droping
# Out:
#        Col1      Col2      Col3
# 0  0.938152  0.867968  0.564309
# 1  0.136084  1.509564  0.413173
# 2 -0.260248  0.305436  1.823351
# 3  0.379587  0.173985 -1.377775
# 4  0.210223 -1.174838 -0.076621
# 5  0.221666 -0.345368 -0.295314
# 6  0.135381 -0.073217  0.614648

# %%
df3
# Out:
#         Col1      Col2      Col3
# 0   0.938152  0.867968  0.564309
# 1   0.136084  1.509564  0.413173
# 2  -0.260248  0.305436  1.823351
# 3   0.379587  0.173985 -1.377775
# 4   0.210223 -1.174838 -0.076621
# 5   0.221666 -0.345368 -0.295314
# 6   0.135381 -0.073217  0.614648
# 7   1.143142  1.258651 -0.015399
# 8  -0.749284  0.083847 -0.551462
# 9   0.729565 -0.425768 -1.117910
# 10  1.744899 -0.915024 -0.513621
# 11  1.093726 -0.103071  2.193583
# 12 -1.222110 -0.545477  0.816354
# 13 -0.707525  0.734215  0.139738
# 14 -0.151864 -0.505305 -0.685257
# 15 -0.031176  0.518940  1.634751
# 16 -1.312724  0.191412  0.699851

# %%
df4 = df3.drop([8,9,10,11,12,13,14,15,16])

# %%
df4
# Out:
#        Col1      Col2      Col3
# 0  0.938152  0.867968  0.564309
# 1  0.136084  1.509564  0.413173
# 2 -0.260248  0.305436  1.823351
# 3  0.379587  0.173985 -1.377775
# 4  0.210223 -1.174838 -0.076621
# 5  0.221666 -0.345368 -0.295314
# 6  0.135381 -0.073217  0.614648
# 7  1.143142  1.258651 -0.015399

# %% [markdown]
# # Covarience - cov

# %%
df4.Col2
# Out:
# 0    0.867968
# 1    1.509564
# 2    0.305436
# 3    0.173985
# 4   -1.174838
# 5   -0.345368
# 6   -0.073217
# 7    1.258651
# Name: Col2, dtype: float64

# %%
df4['Col2']
# Out:
# 0    0.867968
# 1    1.509564
# 2    0.305436
# 3    0.173985
# 4   -1.174838
# 5   -0.345368
# 6   -0.073217
# 7    1.258651
# Name: Col2, dtype: float64

# %%
df4['Col2'].cov(df4['Col3'])
# Out:
# 0.1482895681868981

# %%
df4.Col2.cov(df4.Col3)
# Out:
# 0.1482895681868981

# %%
df4.cov()
# Out:
#           Col1      Col2      Col3
# Col1  0.210679  0.170870 -0.146702
# Col2  0.170870  0.778518  0.148290
# Col3 -0.146702  0.148290  0.834668

# %% [markdown]
# # Co-Relation

# %%
df4.Col2.corr(df4.Col3)
# Out:
# 0.18395832006222693

# %%
df4.corr()
# Out:
#           Col1      Col2      Col3
# Col1  1.000000  0.421911 -0.349840
# Col2  0.421911  1.000000  0.183958
# Col3 -0.349840  0.183958  1.000000

# %%
df4
# Out:
#        Col1      Col2      Col3
# 0  0.938152  0.867968  0.564309
# 1  0.136084  1.509564  0.413173
# 2 -0.260248  0.305436  1.823351
# 3  0.379587  0.173985 -1.377775
# 4  0.210223 -1.174838 -0.076621
# 5  0.221666 -0.345368 -0.295314
# 6  0.135381 -0.073217  0.614648
# 7  1.143142  1.258651 -0.015399

# %% [markdown]
# # Data Cleaning

# %%
df = pd.DataFrame(np.random.randn(5,3),
               index =["A","C","E","B","D"],
               columns = ["Col1","Col2","Col3"])

# %%
df
# Out:
#        Col1      Col2      Col3
# A -1.072056 -1.943772 -2.608180
# C  0.218487 -0.816630  0.568905
# E -0.855272 -0.015506  0.662174
# B -1.476118  1.201057  0.769879
# D -0.753790  0.253455  1.258544

# %%
df = df.reindex(["A","B","C","D","E"])

# %%
df = pd.DataFrame(np.random.randn(5,3),
               index =["A","C","E","f","g"],
               columns = ["Col1","Col2","Col3"])

# %%
df
# Out:
#        Col1      Col2      Col3
# A  0.216472  0.372725  0.030500
# C -0.288714  0.745808  0.654596
# E -1.219805  1.005800 -0.585209
# f -1.341804  1.583704  0.070880
# g  0.350806  0.361607  1.252462

# %%
df = df.reindex(["A","B","C","D","E","F","G","H"])

# %%
df
# Out:
#        Col1      Col2      Col3
# A  0.216472  0.372725  0.030500
# B       NaN       NaN       NaN
# C -0.288714  0.745808  0.654596
# D       NaN       NaN       NaN
# E -1.219805  1.005800 -0.585209
# F       NaN       NaN       NaN
# G       NaN       NaN       NaN
# H       NaN       NaN       NaN

# %% [markdown]
# # isnull() or isna()

# %%
df.isnull()
# Out:
#     Col1   Col2   Col3
# A  False  False  False
# B   True   True   True
# C  False  False  False
# D   True   True   True
# E  False  False  False
# F   True   True   True
# G   True   True   True
# H   True   True   True

# %%
df.isna()
# Out:
#     Col1   Col2   Col3
# A  False  False  False
# B   True   True   True
# C  False  False  False
# D   True   True   True
# E  False  False  False
# F   True   True   True
# G   True   True   True
# H   True   True   True

# %%
df.isnull().sum()
# Out:
# Col1    5
# Col2    5
# Col3    5
# dtype: int64

# %% [markdown]
# # notnull()

# %%
df.notnull()
# Out:
#     Col1   Col2   Col3
# A   True   True   True
# B  False  False  False
# C   True   True   True
# D  False  False  False
# E   True   True   True
# F  False  False  False
# G  False  False  False
# H  False  False  False

# %%
df.notnull().sum()
# Out:
# Col1    3
# Col2    3
# Col3    3
# dtype: int64

# %%
df.count()
# Out:
# Col1    3
# Col2    3
# Col3    3
# dtype: int64

# %%
df.loc['G'].isnull() # for a specific column
# Out:
# Col1    True
# Col2    True
# Col3    True
# Name: G, dtype: bool

# %% [markdown]
# # Cleaning the Missing Value
# * fillna

# %%
df.fillna(10)
# Out:
#         Col1       Col2       Col3
# A   0.216472   0.372725   0.030500
# B  10.000000  10.000000  10.000000
# C  -0.288714   0.745808   0.654596
# D  10.000000  10.000000  10.000000
# E  -1.219805   1.005800  -0.585209
# F  10.000000  10.000000  10.000000
# G  10.000000  10.000000  10.000000
# H  10.000000  10.000000  10.000000

# %%
#Forward Method - pad/fill
#Backword Method - bfill/backfill

# %%
df
# Out:
#        Col1      Col2      Col3
# A  0.216472  0.372725  0.030500
# B       NaN       NaN       NaN
# C -0.288714  0.745808  0.654596
# D       NaN       NaN       NaN
# E -1.219805  1.005800 -0.585209
# F       NaN       NaN       NaN
# G       NaN       NaN       NaN
# H       NaN       NaN       NaN

# %%
df.fillna(method='pad') #pasting same value in the nan places
# Out:
#        Col1      Col2      Col3
# A  0.216472  0.372725  0.030500
# B  0.216472  0.372725  0.030500
# C -0.288714  0.745808  0.654596
# D -0.288714  0.745808  0.654596
# E -1.219805  1.005800 -0.585209
# F -1.219805  1.005800 -0.585209
# G -1.219805  1.005800 -0.585209
# H -1.219805  1.005800 -0.585209

# %%
df.fillna(method='pad',axis = 1)
# Out:
#        Col1      Col2      Col3
# A  0.216472  0.372725  0.030500
# B       NaN       NaN       NaN
# C -0.288714  0.745808  0.654596
# D       NaN       NaN       NaN
# E -1.219805  1.005800 -0.585209
# F       NaN       NaN       NaN
# G       NaN       NaN       NaN
# H       NaN       NaN       NaN

# %%
df.fillna(method='bfill')
# Out:
#        Col1      Col2      Col3
# A  0.216472  0.372725  0.030500
# B -0.288714  0.745808  0.654596
# C -0.288714  0.745808  0.654596
# D -1.219805  1.005800 -0.585209
# E -1.219805  1.005800 -0.585209
# F       NaN       NaN       NaN
# G       NaN       NaN       NaN
# H       NaN       NaN       NaN

# %% [markdown]
# # dropna() to remove all rows which has nan values

# %%
df.dropna()
# Out:
#        Col1      Col2      Col3
# A  0.216472  0.372725  0.030500
# C -0.288714  0.745808  0.654596
# E -1.219805  1.005800 -0.585209

# %% [markdown]
# # Replaceing Mising Values -replace()

# %%
df.replace({0.216472:101,0.654596:121})
# Out:
#        Col1      Col2      Col3
# A  0.216472  0.372725  0.030500
# B       NaN       NaN       NaN
# C -0.288714  0.745808  0.654596
# D       NaN       NaN       NaN
# E -1.219805  1.005800 -0.585209
# F       NaN       NaN       NaN
# G       NaN       NaN       NaN
# H       NaN       NaN       NaN

# %%
df1= pd.DataFrame({"Apples":[50,95,105,75], "Grapes":[90,23,10,56]})

# %%
df1
# Out:
#    Apples  Grapes
# 0      50      90
# 1      95      23
# 2     105      10
# 3      75      56

# %%
df1.replace({50:90,10:55})
# Out:
#    Apples  Grapes
# 0      90      90
# 1      95      23
# 2     105      55
# 3      75      56

# %%
df1.Apples.loc[2] = 500 #remember we can easily gain accees using loc to change any val in any matrix

# %%
df1
# Out:
#    Apples  Grapes
# 0      50      90
# 1      95      23
# 2     500      10
# 3      75      56

# %%
df1.Apples.loc[3] = 50

# %%
df1
# Out:
#    Apples  Grapes
# 0      50      90
# 1      95      23
# 2     500      10
# 3      50      56

# %% [markdown]
# # Handle Duplicate Values

# %%
#1st check the duplicacy --> duplicated()

# %%
df1.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
df1.duplicated(subset=['Apples']) #for a particular column
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %% [markdown]
# #   remove duplicate value

# %%
df1.drop_duplicates(subset=['Apple'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-133-6c351ee98d3f> in <cell line: 1>()
# ----> 1 df1.drop_duplicates(subset=['Apple'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6520         inplace: Literal[False] = ...,
#    6521         ignore_index: bool = ...,
# -> 6522     ) -> DataFrame:
#    6523         ...
#    6524
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    6652
#    6653         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 6654         if isinstance(axis, (tuple, list)):
#    6655             # GH20987
#    6656             raise TypeError("supplying multiple axes to axis is no longer supported.")
#
# KeyError: Index(['Apple'], dtype='object')

# %% [markdown]
# # import & Export the data set

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data = ("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df = pd.read_csv(data)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.to.csv("Name of the file" , "location")

# %%
pd.to_csv("titanic.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
